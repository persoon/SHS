# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from src.gauss import UserExpectation as user

usr = user(88, 191)

usr.showBlackbox()
# Out:
# 88 191 103
# 9.454545454545455
# [0, 156, 344, 450, 498, 400, 279, 142, 10, 14, 150, 214]
